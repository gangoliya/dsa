# %% [markdown]
# In this assignment, you will apply the concepts learned in the first two lessons to:
# - Implement hash tables from scratch in Python
# - Handle hashing collisions using linear probing
# - Replicate the functionality of Python dictionaries

# %% [markdown]
# ## Problem Statement
# In this assignment, you will recreate Python dictionaries from scratch using data structure called _hash table_. Dictionaries in Python are used to store key-value pairs. Keys are used to store and retrieve values. For example, here's a dictionary for storing and retrieving phone numbers using people's name.

# %%
phone_numbers = {
    'Aakash' : '9494949494',
    'Hemanth' : '9696969696',
    'Siddhant' : '9898989898'
}
phone_numbers
# Out:
# {'Aakash': '9494949494', 'Hemanth': '9696969696', 'Siddhant': '9898989898'}

# %%
phone_numbers['Aakash']
# Out:
# '9494949494'

# %%
# Add new value
phone_numbers['Vishal'] = '8787878787'

# Update existing values
phone_numbers['Aakash'] = '7878787878'

# View the updated dictionary
phone_numbers
# Out:
# {'Aakash': '7878787878',
#  'Hemanth': '9696969696',
#  'Siddhant': '9898989898',
#  'Vishal': '8787878787'}

# %%
for name in phone_numbers:
    print('Name: ', name, ', Phone Number: ', phone_numbers[name])
# Out:
# Name:  Aakash , Phone Number:  7878787878
# Name:  Hemanth , Phone Number:  9696969696
# Name:  Siddhant , Phone Number:  9898989898
# Name:  Vishal , Phone Number:  8787878787

# %% [markdown]
# Dictionaries in Python are implemented using the data structure called **hash table**. A hash table uses a list/ array to store the key-value pairs, and uses a hashing function to determine the index for storing or retrieving the data associated with the given key.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Objective:
# To implement a `HashTable` class which supports the following operations:
# 1. **Insert:** Insert a new key-value pair
# 1. **Find:** Find the value associated with a key
# 1. **Update:** Update the value association with a key
# 1. **List:** List all the keys stored in the hash table

# %%
class HashTable:
    def insert(self, key, value):
        """Insert a new key-value pair"""
        pass

    def find(self, key):
        """Find the value associated with a key"""
        pass

    def update(self, key, value):
        """Change the value associated with a key"""
        pass

    def list_all(self):
        """List all the keys"""
        pass

# %%
MAX_HASH_TABLE_SIZE = 4096

# %%
data_list = [None] * 4096

# %%
data_list
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
len(data_list)
# Out:
# 4096

# %%
for item in data_list:
    assert item == None
# assert - If the comparison is True it does nothing if at any point the value was false it will throw error.

# %%
data_list[99] == None
# Out:
# True

# %% [markdown]
# Here's a simple algorithm for hashing, which can convert strings into numeric list indices.
# 1. Iterate over the string, character by character.
# 1. Convert each character to a number using Python's built-in `ord` function.
# 1. Add the numbers for each character to obtain the hash for the entire string.
# 1. Take the remainder of the result with the size of the data list.

# %%
ord('x')
# ord - converts any character or non-numeric number into a numeric number
# Out:
# 120

# %%
32374 % MAX_HASH_TABLE_SIZE
# Out:
# 3702

# %%
def get_index(data_list, a_string):
    # Variable to store the result (updated after each iteration)
    result = 0

    for a_character in a_string:
        # Convert the character to a number (using ord)
        a_number = ord(a_character)
        # Update result by adding the number
        result += a_number

    # Take the remainder of the result with the size of the data list
    list_index = result % len(data_list)
    return list_index

# %%
get_index(data_list, '') == 0
# Out:
# True

# %%
get_index(data_list, 'Aakash') == 585
# Out:
# True

# %%
get_index(data_list, 'Don O Leary') == 941
# Out:
# True

# %%
ord(' ')
# Out:
# 32
